# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavankumar52-coder/DatascienceProjects/blob/main/SqFtOfLandPricePrediction_UsingLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as p

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pavan = '/content/gdrive/MyDrive/practiceDataset.csv'
df = pd.read_csv(pavan)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df.columns[df.isna().any()]
df.LotFrontage = df.LotFrontage.fillna(df.LotFrontage.mean())

# %%
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea  Street Alley LotShape  \
# 0    1          60       RL    65.000000     8450       0   NaN      Reg
# 1    2          20       RL    80.000000     9600       0   NaN      Reg
# 2    3          60       RL    68.000000    11250       0   NaN      IR1
# 3    4          70       RL    60.000000     9550       0   NaN      IR1
# 4    5          60       RL    84.000000    14260       0   NaN      IR1
# 5    6          50       RL    85.000000    14115       0   NaN      IR1
# 6    7          20       RL    75.000000    10084       0   NaN      Reg
# 7    8          60       RL    70.049958    10382       0   NaN      IR1
# 8    9          50       RM    51.000000     6120       0   NaN      Reg
# 9   10         190       RL    50.000000     7420       0   NaN      Reg
# 10  11          20       RL    70.000000    11200       0   NaN      Reg
# 11  12          60       RL    85.000000    11924       0   NaN      IR1
# ...

# %%
df.drop(['MiscFeature'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.drop(['Fence'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.drop(['PoolQC'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.drop(['Alley'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
df.drop(['FireplaceQu'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['Street'] = df['Street'].map({'Pave':0, 'Grvl':1}).astype(int)

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea  Street Alley LotShape  \
# 0   1          60       RL    65.000000     8450       0   NaN      Reg
# 1   2          20       RL    80.000000     9600       0   NaN      Reg
# 2   3          60       RL    68.000000    11250       0   NaN      IR1
# 3   4          70       RL    60.000000     9550       0   NaN      IR1
# 4   5          60       RL    84.000000    14260       0   NaN      IR1
# 5   6          50       RL    85.000000    14115       0   NaN      IR1
# 6   7          20       RL    75.000000    10084       0   NaN      Reg
# 7   8          60       RL    70.049958    10382       0   NaN      IR1
# 8   9          50       RM    51.000000     6120       0   NaN      Reg
# 9  10         190       RL    50.000000     7420       0   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df['CentralAir'] = df['CentralAir'].map({'Y':0,'N':1}).astype(int)

# %%
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea  Street Alley LotShape  \
# 0    1          60       RL    65.000000     8450       0   NaN      Reg
# 1    2          20       RL    80.000000     9600       0   NaN      Reg
# 2    3          60       RL    68.000000    11250       0   NaN      IR1
# 3    4          70       RL    60.000000     9550       0   NaN      IR1
# 4    5          60       RL    84.000000    14260       0   NaN      IR1
# 5    6          50       RL    85.000000    14115       0   NaN      IR1
# 6    7          20       RL    75.000000    10084       0   NaN      Reg
# 7    8          60       RL    70.049958    10382       0   NaN      IR1
# 8    9          50       RM    51.000000     6120       0   NaN      Reg
# 9   10         190       RL    50.000000     7420       0   NaN      Reg
# 10  11          20       RL    70.000000    11200       0   NaN      Reg
# 11  12          60       RL    85.000000    11924       0   NaN      IR1
# ...

# %%
X = df.iloc[:, :1].values

# %%
X
# Out:
# array([[   1],
#        [   2],
#        [   3],
#        ...,
#        [1458],
#        [1459],
#        [1460]])

# %%
y = df.iloc[:,1].values

# %%
y
# Out:
# array([60, 20, 60, ..., 70, 20, 20])

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X, y)
# Out:
# LinearRegression()

# %%
k = [[100]]
PredictedmodelResult = LR.predict(k)
print("Prediction:",PredictedmodelResult)
# Out:
# Prediction: [56.19151573]
